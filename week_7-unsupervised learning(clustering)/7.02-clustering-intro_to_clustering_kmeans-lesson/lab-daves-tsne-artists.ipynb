# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # (optional) Practicing K-Means:  Dave's Artist Pipeline Data
#
# _Authors: Dave Yerrington (SF)_
#
# ![image.png](attachment:image.png)
#
# This artist data was created using Last.fm artist data that was curated by users at the track level.  Each track had a set of user defined genre tags like "rap", "progressive metal", "easy listening", etc.  This genre information was agregated per artist, and each of these genre features aggregated to their mean.  The original matrix was a sampling of 3500 artists having approximately 12000 genre features.  Then, each artist was compared to each other using cosine distance creating an artist to artist similarity matrix.  Each artist was then put into a post-processing to reduce dimensions further, then thrown into non-linear dimensinality reduction pipeline including tSNE (similar to PCA but uses non-linear assumptions for reduction).
#
# This might be more exciting the radioactive isotopes?

# %% [markdown]
# ### User K-Means to explore different areas of the data
# Can you find rap music?

# %%
# Load the data
csv_file = "./daves_artist_tsne_matrix.csv"

# %% [markdown]
# ## Write a function to fit a model, plotting your results.
# It's good to write functions are much as possible to save you time rewriting the same piece of code to visually inspect a cluster.  In the real world, we may not have this luxury when our dataset becomes so large, it's hard to plot.
#
# - Show a scatterplot of the original points
# - Stratify by color

# %%
# A:

# %% [markdown]
# ### How many centroids offer good separation with artists by genre?
# This probably means you need to do a little research on "American" genres.  You might also consider looking at the next question to re-asking this question upon seeing the relationship to average size of cluster.

# %%
# A:

# %% [markdown]
# ### What is the average size of each cluster?
# Based on the K you chose for K-Means, assign the assigned points to their respective clusters that were found from your K-Means model.  How many records are in each cluster and what is the average size?
#
# > Based on this, you may want to change the number of K clusters to find a K that evenly fits your data.

# %%
# A:
