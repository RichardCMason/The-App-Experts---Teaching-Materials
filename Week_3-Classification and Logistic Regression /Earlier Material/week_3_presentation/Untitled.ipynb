# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data = pd.read_csv('./hfi_cc_2018.csv')
data.dropna(subset = ['hf_score'], inplace=True)

# %%
train, test = train_test_split(data, train_size = .75, random_state = 0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1033 entries, 542 to 697
# Columns: 123 entries, year to hf_quartile
# dtypes: float64(119), int64(1), object(3)
# memory usage: 1000.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 1062 to 331
# Columns: 123 entries, year to hf_quartile
# dtypes: float64(119), int64(1), object(3)
# memory usage: 334.2+ KB

# %%
train = train.reset_index(drop = True)

# %%
train.head()
# Out:
#    year ISO_code             countries                      region  \
# 0  2013      GRC                Greece              Eastern Europe
# 1  2012      COG        Congo, Rep. Of          Sub-Saharan Africa
# 2  2009      FJI                  Fiji                     Oceania
# 3  2009      IRL               Ireland              Western Europe
# 4  2011      ARE  United Arab Emirates  Middle East & North Africa
#
#    pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0           6.700000      6.100000         4.600000  5.793651        9.459426
# 1                NaN           NaN              NaN  3.554800        6.053027
# 2                NaN           NaN              NaN  4.343008        8.638445
# 3                NaN           NaN              NaN  7.893729        9.509639
# 4           6.066667      6.037091         7.486491  6.500000        9.764773
#
#    pf_ss_disappearances_disap     ...       ef_regulation_business_bribes  \
# ...

# %%
train.drop(columns = ['hf_rank', 'hf_quartile'], axis = 1, inplace = True)

# %%
train.dropna(subset = ['hf_score'], inplace=True)

# %%
train.to_csv('train.csv')

# %%
test = test.reset_index(drop = True)

# %%
test.head()
# Out:
#    year ISO_code   countries                         region  \
# 0  2010      MDG  Madagascar             Sub-Saharan Africa
# 1  2012      BEL     Belgium                 Western Europe
# 2  2013      MMR     Myanmar                     South Asia
# 3  2016      CHL       Chile  Latin America & the Caribbean
# 4  2015      MLT       Malta                 Western Europe
#
#    pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0           4.300000      5.349745         4.949092  4.900000        6.329103
# 1           8.500000      6.900000         6.700000  7.360317        9.260165
# 2           2.100000      3.900000         3.200000  3.087302        9.037478
# 3           7.706122      6.291439         5.550751  6.516104        8.614887
# 4                NaN           NaN              NaN  7.086754        9.625833
#
#    pf_ss_disappearances_disap     ...       ef_regulation_business_bribes  \
# ...

# %%
test.dropna(subset = ['hf_score'], inplace=True)

# %%
solutions = pd.DataFrame({'Id':test.index,
                          'hf_score': test.hf_score})

# %%
sample_submission = pd.DataFrame({'Id':test.index,
                          'hf_score': test.hf_score.mean()})

# %%
sample_submission.to_csv('sample_submission.csv', index = False)

# %%
solutions.to_csv('solutions.csv', index = False)

# %%
test.drop(columns = ['hf_score', 'hf_rank', 'hf_quartile'], axis = 1, inplace=True)

# %%
test.to_csv('test.csv')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 0 to 344
# Columns: 120 entries, year to ef_rank
# dtypes: float64(116), int64(1), object(3)
# memory usage: 326.1+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1033 entries, 0 to 1032
# Columns: 121 entries, year to hf_score
# dtypes: float64(117), int64(1), object(3)
# memory usage: 984.6+ KB

# %%
train.head()
# Out:
#    year ISO_code             countries                      region  \
# 0  2013      GRC                Greece              Eastern Europe
# 1  2012      COG        Congo, Rep. Of          Sub-Saharan Africa
# 2  2009      FJI                  Fiji                     Oceania
# 3  2009      IRL               Ireland              Western Europe
# 4  2011      ARE  United Arab Emirates  Middle East & North Africa
#
#    pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0           6.700000      6.100000         4.600000  5.793651        9.459426
# 1                NaN           NaN              NaN  3.554800        6.053027
# 2                NaN           NaN              NaN  4.343008        8.638445
# 3                NaN           NaN              NaN  7.893729        9.509639
# 4           6.066667      6.037091         7.486491  6.500000        9.764773
#
#    pf_ss_disappearances_disap    ...     ef_regulation_business_bureaucracy  \
# ...

# %%
corr = train.corr()[['hf_score']].sort_values('hf_score',ascending = False)

# %%
corr[abs(corr.hf_score) >0.5]
# Out:
#                                     hf_score
# hf_score                            1.000000
# pf_score                            0.940239
# pf_rol_procedural                   0.868228
# ef_score                            0.852416
# pf_rol                              0.815282
# ef_legal                            0.807159
# ef_trade                            0.794442
# pf_expression_control               0.754154
# pf_expression_influence             0.733544
# pf_expression                       0.723847
# pf_movement                         0.720264
# ef_money                            0.720184
# pf_ss                               0.719594
# pf_rol_criminal                     0.719137
# pf_rol_civil                        0.714543
# ef_trade_regulatory                 0.711040
# ef_legal_military                   0.708141
# pf_ss_disappearances_organized      0.691557
# ef_trade_movement                   0.684129
# pf_ss_women_inheritance_daughters   0.677153
# ...

# %%
train.head()
# Out:
#    year ISO_code             countries                      region  \
# 0  2013      GRC                Greece              Eastern Europe
# 1  2012      COG        Congo, Rep. Of          Sub-Saharan Africa
# 2  2009      FJI                  Fiji                     Oceania
# 3  2009      IRL               Ireland              Western Europe
# 4  2011      ARE  United Arab Emirates  Middle East & North Africa
#
#    pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0           6.700000      6.100000         4.600000  5.793651        9.459426
# 1                NaN           NaN              NaN  3.554800        6.053027
# 2                NaN           NaN              NaN  4.343008        8.638445
# 3                NaN           NaN              NaN  7.893729        9.509639
# 4           6.066667      6.037091         7.486491  6.500000        9.764773
#
#    pf_ss_disappearances_disap    ...     ef_regulation_business_bureaucracy  \
# ...

# %%
test.head()
# Out:
#    year ISO_code   countries                         region  \
# 0  2010      MDG  Madagascar             Sub-Saharan Africa
# 1  2012      BEL     Belgium                 Western Europe
# 2  2013      MMR     Myanmar                     South Asia
# 3  2016      CHL       Chile  Latin America & the Caribbean
# 4  2015      MLT       Malta                 Western Europe
#
#    pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0           4.300000      5.349745         4.949092  4.900000        6.329103
# 1           8.500000      6.900000         6.700000  7.360317        9.260165
# 2           2.100000      3.900000         3.200000  3.087302        9.037478
# 3           7.706122      6.291439         5.550751  6.516104        8.614887
# 4                NaN           NaN              NaN  7.086754        9.625833
#
#    pf_ss_disappearances_disap   ...     ef_regulation_business_adm  \
# ...

# %%
test.head()
# Out:
#    year ISO_code   countries                         region  \
# 0  2010      MDG  Madagascar             Sub-Saharan Africa
# 1  2012      BEL     Belgium                 Western Europe
# 2  2013      MMR     Myanmar                     South Asia
# 3  2016      CHL       Chile  Latin America & the Caribbean
# 4  2015      MLT       Malta                 Western Europe
#
#    pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0           4.300000      5.349745         4.949092  4.900000        6.329103
# 1           8.500000      6.900000         6.700000  7.360317        9.260165
# 2           2.100000      3.900000         3.200000  3.087302        9.037478
# 3           7.706122      6.291439         5.550751  6.516104        8.614887
# 4                NaN           NaN              NaN  7.086754        9.625833
#
#    pf_ss_disappearances_disap   ...     ef_regulation_business_adm  \
# ...

# %%
sample_submission
# Out:
#       Id  hf_score
# 0      0  6.927536
# 1      1  6.927536
# 2      2  6.927536
# 3      3  6.927536
# 4      4  6.927536
# 5      5  6.927536
# 6      6  6.927536
# 7      7  6.927536
# 8      8  6.927536
# 9      9  6.927536
# 10    10  6.927536
# 11    11  6.927536
# 12    12  6.927536
# 13    13  6.927536
# 14    14  6.927536
# 15    15  6.927536
# 16    16  6.927536
# 17    17  6.927536
# 18    18  6.927536
# 19    19  6.927536
# 20    20  6.927536
# 21    21  6.927536
# 22    22  6.927536
# 23    23  6.927536
# 24    24  6.927536
# 25    25  6.927536
# 26    26  6.927536
# 27    27  6.927536
# 28    28  6.927536
# 29    29  6.927536
# ..   ...       ...
# 315  315  6.927536
# 316  316  6.927536
# 317  317  6.927536
# 318  318  6.927536
# 319  319  6.927536
# 320  320  6.927536
# 321  321  6.927536
# 322  322  6.927536
# 323  323  6.927536
# 324  324  6.927536
# 325  325  6.927536
# 326  326  6.927536
# 327  327  6.927536
# 328  328  6.927536
# 329  329  6.927536
# ...
